# %% [markdown]
# ### Exploring the Enron dataset (emails + finances);
#
#
#
#     - loads up the dataset (pickled dict of dicts).
#
#     The dataset has the form:
#
#         *  enron_data["LASTNAME FIRSTNAME MIDDLEINITIAL"] = { features_dict }
#
#        *  {features_dict} is a dictionary of features associated with that person.
#
#     You should explore features_dict as part of the mini-project, but here's an example to get you started:
#
#
#     enron_data["SKILLING JEFFREY K"]["bonus"] = 5600000

# %% [markdown]
# ---

# %% [markdown]
# #### Libraries

# %%
#Import Libbraries
import pickle
import pandas as pd
import numpy as np

# %% [markdown]
# #### Data Location and Load

# %%
#Location of the pickled data
dir = "../final_project/final_project_dataset.pkl"

# %%
#Load the pickled data to Dataframe
enron = pd.read_pickle(dir)

# %% [markdown]
# #### Dictionary data into Dataframe

# %%
enron = pd.DataFrame.from_dict(enron, orient='index', dtype=float)
enron[:5]
# Out:
#                       salary  to_messages  deferral_payments  total_payments  \
# ALLEN PHILLIP K     201955.0       2902.0          2869717.0       4484442.0
# BADUM JAMES P            NaN          NaN           178980.0        182466.0
# BANNANTINE JAMES M     477.0        566.0                NaN        916197.0
# BAXTER JOHN C       267102.0          NaN          1295738.0       5634343.0
# BAY FRANKLIN R      239671.0          NaN           260455.0        827696.0
#
#                     loan_advances      bonus               email_address  \
# ALLEN PHILLIP K               NaN  4175000.0     phillip.allen@enron.com
# BADUM JAMES P                 NaN        NaN                         NaN
# BANNANTINE JAMES M            NaN        NaN  james.bannantine@enron.com
# BAXTER JOHN C                 NaN  1200000.0                         NaN
# BAY FRANKLIN R                NaN   400000.0         frank.bay@enron.com
#
# ...

# %% [markdown]
# #### Data Exploration

# %%
enron.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 146 entries, ALLEN PHILLIP K to YEAP SOON
# Data columns (total 21 columns):
# salary                       95 non-null float64
# to_messages                  86 non-null float64
# deferral_payments            39 non-null float64
# total_payments               125 non-null float64
# loan_advances                4 non-null float64
# bonus                        82 non-null float64
# email_address                146 non-null object
# restricted_stock_deferred    18 non-null float64
# deferred_income              49 non-null float64
# total_stock_value            126 non-null float64
# expenses                     95 non-null float64
# from_poi_to_this_person      86 non-null float64
# exercised_stock_options      102 non-null float64
# from_messages                86 non-null float64
# other                        93 non-null float64
# from_this_person_to_poi      86 non-null float64
# poi                          146 non-null float64
# ...

# %%
enron.poi.unique()
# Out:
# array([0., 1.])

# %%
#Count number of Person of Interrest(POI)
poi_count = len(enron.loc[enron['poi'] == True])
print("Number of Person of Interest: {}".format(poi_count))
# Out:
# Number of Person of Interest: 18

# %%
enron.describe()
# Out:
#              salary   to_messages  deferral_payments  total_payments  \
# count  9.500000e+01     86.000000       3.900000e+01    1.250000e+02
# mean   5.621943e+05   2073.860465       1.642674e+06    5.081526e+06
# std    2.716369e+06   2582.700981       5.161930e+06    2.906172e+07
# min    4.770000e+02     57.000000      -1.025000e+05    1.480000e+02
# 25%    2.118160e+05    541.250000       8.157300e+04    3.944750e+05
# 50%    2.599960e+05   1211.000000       2.274490e+05    1.101393e+06
# 75%    3.121170e+05   2634.750000       1.002672e+06    2.093263e+06
# max    2.670423e+07  15149.000000       3.208340e+07    3.098866e+08
#
#        loan_advances         bonus  restricted_stock_deferred  \
# count   4.000000e+00  8.200000e+01               1.800000e+01
# mean    4.196250e+07  2.374235e+06               1.664106e+05
# std     4.708321e+07  1.071333e+07               4.201494e+06
# min     4.000000e+05  7.000000e+04              -7.576788e+06
# ...

# %%
missing = pd.DataFrame({'Null Values':enron.isna().sum(), 'percent':enron.isna().mean()*100})

# %%
missing.sort_values(by='Null Values', ascending=False)
# Out:
#                            Null Values    percent
# loan_advances                      142  97.260274
# director_fees                      129  88.356164
# restricted_stock_deferred          128  87.671233
# deferral_payments                  107  73.287671
# deferred_income                     97  66.438356
# long_term_incentive                 80  54.794521
# bonus                               64  43.835616
# from_messages                       60  41.095890
# shared_receipt_with_poi             60  41.095890
# from_this_person_to_poi             60  41.095890
# to_messages                         60  41.095890
# from_poi_to_this_person             60  41.095890
# other                               53  36.301370
# salary                              51  34.931507
# expenses                            51  34.931507
# exercised_stock_options             44  30.136986
# restricted_stock                    36  24.657534
# total_payments                      21  14.383562
# ...

# %% [markdown]
# #### Load the Name List Text File

# %%
nfile = '../final_project/poi_names.txt'

# %%
namesdf = pd.read_csv(nfile, delimiter=')',names=('poi', 'Name'),\
                      index_col='Name', skiprows=[0])
namesdf[:5]
# Out:
#                    poi
# Name
#  Lay, Kenneth       (y
#  Skilling, Jeffrey  (y
#  Howard, Kevin      (n
#  Krautz, Michael    (n
#  Yeager, Scott      (n

# %%
namesdf = namesdf.replace('[(]', '', regex=True)
namesdf.sort_values(by='Name', ascending=True)
# Out:
#                      poi
# Name
#  Bayley, Daniel        n
#  Belden, Timothy       n
#  Bermingham, David     n
#  Bowen, Raymond        n
#  Boyle, Dan            n
#  Brown, James          n
#  Calger, Christopher   n
#  Causey, Richard       n
#  Colwell, Wesley       n
#  Darby, Giles          n
#  DeSpain, Timothy      n
#  Delainey, David       y
#  Duncan, David         n
#  Fastow, Andrew        n
#  Fastow, Lea           n
#  Forney, John          y
#  Fuhs, William         n
#  Furst, Robert         n
#  Glisan, Ben           n
#  Hannon, Kevin         n
#  Hirko, Joseph         n
#  Howard, Kevin         n
#  Koenig, Mark          n
#  Kopper, Michael       n
#  Krautz, Michael       n
#  Lawyer, Larry         n
#  Lay, Kenneth          y
#  Loehr, Christopher    n
#  Mulgrew, Gary         n
#  Rice, Kenneth         n
#  Richter, Jeffrey      n
#  Rieker, Paula         n
#  Shelby, Rex           n
#  Skilling, Jeffrey     y
#  Yeager, Scott         n

# %%
# Get quick count of rows in a DataFrame
len(namesdf.index)
# Out:
# 35
